# %%
import cv2
from ultralytics import YOLO

# %%
import cv2
from ultralytics import YOLO

# Load the YOLOv8 model
model = YOLO("yolov8n.pt")
# Load the image
image_path = "image2.jpeg"
image = cv2.imread(image_path)
height, width, channels = image.shape

# Manually noted coordinates of the A4 paper bounding box
# a4_x1, a4_y1 = 100, 100  # Replace with actual values
# a4_x2, a4_y2 = 600, 800  # Replace with actual values

# Calculate the width and height in pixels
a4_width_pixels = width
a4_height_pixels = height

# Real-world dimensions of the A4 paper (in cm)
A4_WIDTH_CM = 21.0
A4_HEIGHT_CM = 29.7

# Calculate the conversion factors
cm_per_pixel_width = A4_WIDTH_CM / a4_width_pixels
cm_per_pixel_height = A4_HEIGHT_CM / a4_height_pixels



# Run YOLOv8 detection on the image
results = model.predict(image)

# Extract the detections from the results
detections = results[0].boxes

# Loop through the detections
for detection in detections:
    # Get the bounding box coordinates
    x1, y1, x2, y2 = map(int, detection.xyxy[0])
    
    # Calculate the width and height of the bounding box in pixels
    width_pixels = x2 - x1
    height_pixels = y2 - y1

    # Convert the width and height to centimeters
    width_cm = width_pixels * cm_per_pixel_width
    height_cm = height_pixels * cm_per_pixel_height

    # Draw the bounding box on the image
    cv2.rectangle(image, (x1, y1), (x2, y2), (0, 255, 0), 2)

    # Display the width and height in cm on the image
    label = f"W: {width_cm:.2f} cm, H: {height_cm:.2f} cm"
    cv2.putText(image, label, (x1, y1 - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 255, 0), 2)

# Display the annotated image
cv2.imshow("YOLOv8 Detection", image)
cv2.waitKey(0)
cv2.destroyAllWindows()

# Save the annotated image
cv2.imwrite('Detected_objects_with_dimensions.png', image)
# Out:
# 0: 640x480 1 cell phone, 125.0ms
# Speed: 6.1ms preprocess, 125.0ms inference, 6.5ms postprocess per image at shape (1, 3, 640, 480)
# True

# %%
import cv2
from ultralytics import YOLO

# Load the YOLOv8 model
model = YOLO("yolov8n.pt")

# Define the class ID for a phone
# PHONE_CLASS_ID = 67

# Manually noted coordinates of the A4 paper bounding box
# x1, y1 = 100, 100  # Replace with actual values
# x2, y2 = 600, 800  # Replace with actual values

# Calculate the width and height in pixels
# a4_width_pixels = x2 - x1
# a4_height_pixels = y2 - y1

# Real-world dimensions of the A4 paper (in cm)
A4_WIDTH_CM = 21.0
A4_HEIGHT_CM = 29.7

# # Calculate the conversion factors
# cm_per_pixel_width = A4_WIDTH_CM / a4_width_pixels
# cm_per_pixel_height = A4_HEIGHT_CM / a4_height_pixels

# Open the video file
cap = cv2.VideoCapture('video-phone-case.mp4')

# Loop through the video frames
while cap.isOpened():
    # Read a frame from the video
    success, frame = cap.read()
    height, width, channels = frame.shape
    a4_width_pixels = width
    a4_height_pixels = height
    cm_per_pixel_width = A4_WIDTH_CM / a4_width_pixels
    cm_per_pixel_height = A4_HEIGHT_CM / a4_height_pixels
    if success:
        # Run YOLOv8 detection on the frame
        results = model.track(frame, persist=True)

        # Extract the detections from the results
        detections = results[0].boxes

        # Loop through the detections
        for detection in detections:
            # # Get the class ID of the detection
            # class_id = int(detection.cls[0])


            # Get the bounding box coordinates
            x1, y1, x2, y2 = map(int, detection.xyxy[0])
                
            # Calculate the width and height of the bounding box in pixels
            width_pixels = x2 - x1
            height_pixels = y2 - y1

            # Convert the width and height to centimeters
            width_cm = width_pixels * cm_per_pixel_width
            height_cm = height_pixels * cm_per_pixel_height

            # Draw the bounding box on the frame
            cv2.rectangle(frame, (x1, y1), (x2, y2), (0, 255, 0), 2)

            # Display the width and height in cm on the frame
            label = f"W: {width_cm:.2f} cm, H: {height_cm:.2f} cm"
            cv2.putText(frame, label, (x1, y1 - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 255, 0), 2)
        
        # Display the annotated frame
        cv2.imshow("YOLOv8 Tracking", frame)

        # Break the loop if 'q' is pressed
        if cv2.waitKey(1) & 0xFF == ord("q"):
            break
    else:
        # Break the loop if the end of the video is reached
        break

# Release the video capture object and close the display window
cap.release()
cv2.destroyAllWindows()
# Out:
# [aac @ 0x16a8b8c50] Input buffer exhausted before END element found
# 0: 384x640 (no detections), 69.5ms
# Speed: 1.7ms preprocess, 69.5ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 80
1ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 kite, 75.3ms
# Speed: 1.6ms preprocess, 75.3ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 traffic light, 1 kite, 66.6ms
# Speed: 2.8ms preprocess, 66.6ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bird, 1 cell phone, 61.8ms
# Speed: 1.4ms preprocess, 61.8ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 cell phone, 64.8ms
# Speed: 1.3ms preprocess, 64.8ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 63.0ms
# Speed: 1.2ms preprocess, 63.0ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 stop sign, 1 kite, 63.3ms
# Speed: 1.4ms preprocess, 63.3ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bird, 63.7ms
# Speed: 1.4ms preprocess, 63.7ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 bird, 63.1ms
# Speed: 1.2ms preprocess, 63.1ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 stop sign, 63.0ms
# Speed: 1.5ms preprocess, 63.0ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 surfboard, 62.4ms
# Speed: 1.3ms preprocess, 62.4ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 stop sign, 1 surfboard, 64.1ms
# Speed: 1.4ms preprocess, 64.1ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 snowboard, 1 surfboard, 62.6ms
# Speed: 1.3ms preprocess, 62.6ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 snowboard, 64.1ms
# Speed: 1.3ms preprocess, 64.1ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 snowboard, 63.7ms
# Speed: 1.4ms preprocess, 63.7ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 65.4ms
# Speed: 1.3ms preprocess, 65.4ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 1 cell phone, 68.1ms
# Speed: 1.3ms preprocess, 68.1ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 1 cell phone, 65.2ms
# Speed: 1.4ms preprocess, 65.2ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 1 cell phone, 64.9ms
# Speed: 1.6ms preprocess, 64.9ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 cell phone, 64.9ms
# Speed: 1.4ms preprocess, 64.9ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 1 cell phone, 64.1ms
# Speed: 1.4ms preprocess, 64.1ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 63.8ms
# Speed: 1.6ms preprocess, 63.8ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 63.4ms
# Speed: 1.4ms preprocess, 63.4ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 63.6ms
# Speed: 1.6ms preprocess, 63.6ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 63.7ms
# Speed: 1.4ms preprocess, 63.7ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 63.4ms
# Speed: 1.4ms preprocess, 63.4ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 64.7ms
# Speed: 1.3ms preprocess, 64.7ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 64.3ms
# Speed: 1.4ms preprocess, 64.3ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 scissors, 62.8ms
# Speed: 1.3ms preprocess, 62.8ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 65.3ms
# Speed: 1.6ms preprocess, 65.3ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 64.9ms
# Speed: 1.7ms preprocess, 64.9ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 63.4ms
# Speed: 1.4ms preprocess, 63.4ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 64.5ms
# Speed: 1.3ms preprocess, 64.5ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 62.0ms
# Speed: 1.4ms preprocess, 62.0ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 63.9ms
# Speed: 1.4ms preprocess, 63.9ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 cell phone, 64.2ms
# Speed: 1.8ms preprocess, 64.2ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 63.0ms
# Speed: 1.3ms preprocess, 63.0ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 63.3ms
# Speed: 1.7ms preprocess, 63.3ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 cell phone, 64.4ms
# Speed: 1.5ms preprocess, 64.4ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 cell phone, 64.4ms
# Speed: 1.4ms preprocess, 64.4ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 cell phone, 63.7ms
# Speed: 1.4ms preprocess, 63.7ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 cell phone, 63.2ms
# Speed: 1.4ms preprocess, 63.2ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 cell phone, 65.0ms
# Speed: 1.4ms preprocess, 65.0ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 cell phone, 62.4ms
# Speed: 1.3ms preprocess, 62.4ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 cell phone, 62.0ms
# Speed: 1.6ms preprocess, 62.0ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 cell phone, 63.9ms
# Speed: 1.5ms preprocess, 63.9ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 cell phone, 63.0ms
# Speed: 1.3ms preprocess, 63.0ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 63.3ms
# Speed: 1.4ms preprocess, 63.3ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 62.7ms
# Speed: 1.3ms preprocess, 62.7ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 65.0ms
# Speed: 1.2ms preprocess, 65.0ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 cell phone, 63.4ms
# Speed: 1.4ms preprocess, 63.4ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 cell phone, 64.1ms
# Speed: 1.4ms preprocess, 64.1ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 cell phone, 63.8ms
# Speed: 1.3ms preprocess, 63.8ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 cell phone, 64.2ms
# Speed: 1.2ms preprocess, 64.2ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 cell phone, 62.7ms
# Speed: 1.4ms preprocess, 62.7ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 cell phone, 63.1ms
# Speed: 1.3ms preprocess, 63.1ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 cell phone, 64.9ms
# Speed: 1.2ms preprocess, 64.9ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 cell phone, 63.1ms
# Speed: 1.5ms preprocess, 63.1ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 cell phone, 64.5ms
# Speed: 1.3ms preprocess, 64.5ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 cell phone, 62.6ms
# Speed: 1.4ms preprocess, 62.6ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 cell phone, 63.6ms
# Speed: 1.5ms preprocess, 63.6ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 cell phone, 64.1ms
# Speed: 1.6ms preprocess, 64.1ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 cell phone, 64.1ms
# Speed: 1.3ms preprocess, 64.1ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 cell phone, 63.2ms
# Speed: 1.6ms preprocess, 63.2ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 cell phone, 64.1ms
# Speed: 1.4ms preprocess, 64.1ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 64.2ms
# Speed: 1.3ms preprocess, 64.2ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 66.1ms
# Speed: 1.3ms preprocess, 66.1ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 62.4ms
# Speed: 1.5ms preprocess, 62.4ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 63.4ms
# Speed: 1.7ms preprocess, 63.4ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 cell phone, 63.7ms
# Speed: 1.4ms preprocess, 63.7ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 64.1ms
# Speed: 1.4ms preprocess, 64.1ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 62.7ms
# Speed: 1.4ms preprocess, 62.7ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 63.3ms
# Speed: 1.3ms preprocess, 63.3ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 61.6ms
# Speed: 1.6ms preprocess, 61.6ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 63.0ms
# Speed: 1.5ms preprocess, 63.0ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 cell phone, 63.5ms
# Speed: 1.6ms preprocess, 63.5ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 64.3ms
# Speed: 1.2ms preprocess, 64.3ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 62.2ms
# Speed: 1.6ms preprocess, 62.2ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 64.9ms
# Speed: 1.4ms preprocess, 64.9ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 64.1ms
# Speed: 1.3ms preprocess, 64.1ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 63.6ms
# Speed: 1.5ms preprocess, 63.6ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 62.6ms
# Speed: 1.6ms preprocess, 62.6ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 62.6ms
# Speed: 1.2ms preprocess, 62.6ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 62.0ms
# Speed: 1.6ms preprocess, 62.0ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 62.7ms
# Speed: 1.3ms preprocess, 62.7ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 64.2ms
# Speed: 1.3ms preprocess, 64.2ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 63.4ms
# Speed: 1.7ms preprocess, 63.4ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 62.8ms
# Speed: 1.3ms preprocess, 62.8ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 63.0ms
# Speed: 1.7ms preprocess, 63.0ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 cell phone, 62.5ms
# Speed: 1.3ms preprocess, 62.5ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 cell phone, 63.2ms
# Speed: 1.6ms preprocess, 63.2ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 cell phone, 63.8ms
# Speed: 1.6ms preprocess, 63.8ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 cell phone, 63.0ms
# Speed: 1.3ms preprocess, 63.0ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 cell phone, 63.8ms
# Speed: 1.6ms preprocess, 63.8ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 cell phone, 63.0ms
# Speed: 1.7ms preprocess, 63.0ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 cell phone, 62.0ms
# Speed: 1.6ms preprocess, 62.0ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 cell phone, 63.6ms
# Speed: 1.3ms preprocess, 63.6ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 cell phone, 62.4ms
# Speed: 1.6ms preprocess, 62.4ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 cell phone, 64.0ms
# Speed: 1.7ms preprocess, 64.0ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 cell phone, 63.3ms
# Speed: 1.6ms preprocess, 63.3ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 cell phone, 64.1ms
# Speed: 1.3ms preprocess, 64.1ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 63.6ms
# Speed: 1.6ms preprocess, 63.6ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 stop sign, 63.1ms
# Speed: 1.5ms preprocess, 63.1ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 65.1ms
# Speed: 2.6ms preprocess, 65.1ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 stop sign, 63.9ms
# Speed: 1.4ms preprocess, 63.9ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 stop sign, 62.0ms
# Speed: 1.3ms preprocess, 62.0ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 stop sign, 65.0ms
# Speed: 1.6ms preprocess, 65.0ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 63.5ms
# Speed: 1.4ms preprocess, 63.5ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 63.6ms
# Speed: 1.5ms preprocess, 63.6ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 63.5ms
# Speed: 1.6ms preprocess, 63.5ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 62.4ms
# Speed: 1.3ms preprocess, 62.4ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 cell phone, 63.2ms
# Speed: 1.3ms preprocess, 63.2ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 cell phone, 63.9ms
# Speed: 1.7ms preprocess, 63.9ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 stop sign, 63.1ms
# Speed: 1.4ms preprocess, 63.1ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 cell phone, 64.6ms
# Speed: 1.5ms preprocess, 64.6ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 69.5ms
# Speed: 1.4ms preprocess, 69.5ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 63.8ms
# Speed: 1.3ms preprocess, 63.8ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 cell phone, 63.5ms
# Speed: 1.4ms preprocess, 63.5ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 cell phone, 65.0ms
# Speed: 1.4ms preprocess, 65.0ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 cell phone, 64.0ms
# Speed: 1.6ms preprocess, 64.0ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 64.0ms
# Speed: 1.3ms preprocess, 64.0ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 63.4ms
# Speed: 1.6ms preprocess, 63.4ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 62.8ms
# Speed: 1.4ms preprocess, 62.8ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 cell phone, 63.7ms
# Speed: 1.3ms preprocess, 63.7ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 1 suitcase, 1 cell phone, 63.2ms
# Speed: 1.2ms preprocess, 63.2ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 1 suitcase, 1 cell phone, 63.9ms
# Speed: 1.6ms preprocess, 63.9ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 1 cell phone, 63.9ms
# Speed: 1.4ms preprocess, 63.9ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 62.9ms
# Speed: 1.6ms preprocess, 62.9ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 64.0ms
# Speed: 1.6ms preprocess, 64.0ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 63.5ms
# Speed: 1.6ms preprocess, 63.5ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 63.2ms
# Speed: 1.4ms preprocess, 63.2ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 64.2ms
# Speed: 1.4ms preprocess, 64.2ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 63.5ms
# Speed: 1.4ms preprocess, 63.5ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 63.2ms
# Speed: 1.4ms preprocess, 63.2ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 62.0ms
# Speed: 1.5ms preprocess, 62.0ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 63.4ms
# Speed: 1.3ms preprocess, 63.4ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 63.9ms
# Speed: 1.6ms preprocess, 63.9ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 63.1ms
# Speed: 1.3ms preprocess, 63.1ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 63.9ms
# Speed: 1.2ms preprocess, 63.9ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 63.5ms
# Speed: 1.6ms preprocess, 63.5ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 63.7ms
# Speed: 1.6ms preprocess, 63.7ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 63.1ms
# Speed: 1.4ms preprocess, 63.1ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 63.9ms
# Speed: 1.8ms preprocess, 63.9ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 62.0ms
# Speed: 1.6ms preprocess, 62.0ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 63.9ms
# Speed: 1.6ms preprocess, 63.9ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 62.9ms
# Speed: 1.7ms preprocess, 62.9ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 64.1ms
# Speed: 1.4ms preprocess, 64.1ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 cell phone, 63.2ms
# Speed: 1.5ms preprocess, 63.2ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 cell phone, 63.5ms
# Speed: 1.3ms preprocess, 63.5ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 cell phone, 63.5ms
# Speed: 1.4ms preprocess, 63.5ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 cell phone, 64.0ms
# Speed: 1.3ms preprocess, 64.0ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 cell phone, 64.7ms
# Speed: 1.6ms preprocess, 64.7ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 cell phone, 63.0ms
# Speed: 1.3ms preprocess, 63.0ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cell phones, 63.5ms
# Speed: 1.3ms preprocess, 63.5ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 cell phone, 64.2ms
# Speed: 1.6ms preprocess, 64.2ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 cell phone, 65.4ms
# Speed: 2.0ms preprocess, 65.4ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 cell phone, 64.3ms
# Speed: 1.6ms preprocess, 64.3ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 cell phone, 64.9ms
# Speed: 1.7ms preprocess, 64.9ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 cell phone, 65.3ms
# Speed: 1.3ms preprocess, 65.3ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 cell phone, 62.7ms
# Speed: 1.7ms preprocess, 62.7ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 cell phone, 64.2ms
# Speed: 1.4ms preprocess, 64.2ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 cell phone, 65.0ms
# Speed: 1.5ms preprocess, 65.0ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 cell phone, 64.7ms
# Speed: 1.4ms preprocess, 64.7ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 cell phone, 67.0ms
# Speed: 1.7ms preprocess, 67.0ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 cell phone, 64.3ms
# Speed: 1.6ms preprocess, 64.3ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 cell phone, 61.6ms
# Speed: 1.6ms preprocess, 61.6ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 cell phone, 63.9ms
# Speed: 1.6ms preprocess, 63.9ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 cell phone, 63.3ms
# Speed: 1.6ms preprocess, 63.3ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 64.5ms
# Speed: 1.3ms preprocess, 64.5ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 62.6ms
# Speed: 1.2ms preprocess, 62.6ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 65.8ms
# Speed: 1.5ms preprocess, 65.8ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 cell phone, 64.2ms
# Speed: 1.4ms preprocess, 64.2ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 cell phone, 62.8ms
# Speed: 1.6ms preprocess, 62.8ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 cell phone, 62.5ms
# Speed: 1.7ms preprocess, 62.5ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 cell phone, 64.7ms
# Speed: 1.6ms preprocess, 64.7ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 cell phone, 64.3ms
# Speed: 1.4ms preprocess, 64.3ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 cell phone, 64.5ms
# Speed: 1.4ms preprocess, 64.5ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 cell phone, 62.4ms
# Speed: 1.2ms preprocess, 62.4ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 cell phone, 63.6ms
# Speed: 1.2ms preprocess, 63.6ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 cell phone, 62.8ms
# Speed: 1.6ms preprocess, 62.8ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 cell phone, 63.5ms
# Speed: 1.2ms preprocess, 63.5ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 cell phone, 62.5ms
# Speed: 1.7ms preprocess, 62.5ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 cell phone, 62.7ms
# Speed: 1.6ms preprocess, 62.7ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 cell phone, 62.9ms
# Speed: 1.6ms preprocess, 62.9ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 cell phone, 64.6ms
# Speed: 1.6ms preprocess, 64.6ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 cell phone, 63.2ms
# Speed: 1.5ms preprocess, 63.2ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 cell phone, 65.0ms
# Speed: 1.8ms preprocess, 65.0ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 cell phone, 63.9ms
# Speed: 1.3ms preprocess, 63.9ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 cell phone, 63.5ms
# Speed: 1.3ms preprocess, 63.5ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 cell phone, 62.8ms
# Speed: 1.4ms preprocess, 62.8ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 cell phone, 63.4ms
# Speed: 1.3ms preprocess, 63.4ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 cell phone, 64.1ms
# Speed: 1.3ms preprocess, 64.1ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 cell phone, 64.5ms
# Speed: 1.4ms preprocess, 64.5ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 cell phone, 65.2ms
# Speed: 1.3ms preprocess, 65.2ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 cell phone, 64.3ms
# Speed: 1.4ms preprocess, 64.3ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 cell phone, 63.9ms
# Speed: 1.6ms preprocess, 63.9ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 cell phone, 64.9ms
# Speed: 1.3ms preprocess, 64.9ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 cell phone, 61.6ms
# Speed: 1.5ms preprocess, 61.6ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 cell phone, 63.9ms
# Speed: 1.3ms preprocess, 63.9ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 cell phone, 64.6ms
# Speed: 1.5ms preprocess, 64.6ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 remote, 62.6ms
# Speed: 1.6ms preprocess, 62.6ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 remote, 63.3ms
# Speed: 1.6ms preprocess, 63.3ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 remote, 63.0ms
# Speed: 1.7ms preprocess, 63.0ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 remote, 63.4ms
# Speed: 1.6ms preprocess, 63.4ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 remote, 63.0ms
# Speed: 1.4ms preprocess, 63.0ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 remote, 62.3ms
# Speed: 1.3ms preprocess, 62.3ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 cell phone, 62.7ms
# Speed: 1.3ms preprocess, 62.7ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 cell phone, 64.6ms
# Speed: 1.4ms preprocess, 64.6ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 cell phone, 62.9ms
# Speed: 1.4ms preprocess, 62.9ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 cell phone, 64.0ms
# Speed: 1.4ms preprocess, 64.0ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 cell phone, 68.1ms
# Speed: 1.4ms preprocess, 68.1ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 cell phone, 63.2ms
# Speed: 1.7ms preprocess, 63.2ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 cell phone, 63.4ms
# Speed: 1.6ms preprocess, 63.4ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 cell phone, 62.8ms
# Speed: 1.7ms preprocess, 62.8ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 cell phone, 66.4ms
# Speed: 1.4ms preprocess, 66.4ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 cell phone, 62.6ms
# Speed: 1.4ms preprocess, 62.6ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 cell phone, 63.1ms
# Speed: 1.4ms preprocess, 63.1ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 cell phone, 63.9ms
# Speed: 1.4ms preprocess, 63.9ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 cell phone, 64.3ms
# Speed: 1.3ms preprocess, 64.3ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 cell phone, 63.0ms
# Speed: 1.5ms preprocess, 63.0ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 cell phone, 64.3ms
# Speed: 1.4ms preprocess, 64.3ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 cell phone, 64.0ms
# Speed: 1.5ms preprocess, 64.0ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 cell phone, 68.0ms
# Speed: 1.3ms preprocess, 68.0ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 cell phone, 64.9ms
# Speed: 1.4ms preprocess, 64.9ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 remote, 63.5ms
# Speed: 1.6ms preprocess, 63.5ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 remote, 63.9ms
# Speed: 1.4ms preprocess, 63.9ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 cell phone, 64.0ms
# Speed: 1.3ms preprocess, 64.0ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 63.2ms
# Speed: 1.4ms preprocess, 63.2ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 cell phone, 64.0ms
# Speed: 1.2ms preprocess, 64.0ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 cell phone, 63.4ms
# Speed: 1.6ms preprocess, 63.4ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 remote, 63.6ms
# Speed: 1.6ms preprocess, 63.6ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 cell phone, 63.8ms
# Speed: 1.3ms preprocess, 63.8ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 cell phone, 64.3ms
# Speed: 1.4ms preprocess, 64.3ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 cell phone, 64.0ms
# Speed: 1.3ms preprocess, 64.0ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 cell phone, 64.4ms
# Speed: 1.3ms preprocess, 64.4ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 cell phone, 63.2ms
# Speed: 1.6ms preprocess, 63.2ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 cell phone, 63.7ms
# Speed: 1.4ms preprocess, 63.7ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 cell phone, 64.1ms
# Speed: 1.6ms preprocess, 64.1ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 cell phone, 62.2ms
# Speed: 1.6ms preprocess, 62.2ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 cell phone, 64.0ms
# Speed: 1.3ms preprocess, 64.0ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 cell phone, 63.0ms
# Speed: 1.2ms preprocess, 63.0ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 cell phone, 63.5ms
# Speed: 1.2ms preprocess, 63.5ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 cell phone, 63.0ms
# Speed: 1.6ms preprocess, 63.0ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 cell phone, 62.8ms
# Speed: 1.4ms preprocess, 62.8ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 cell phone, 64.1ms
# Speed: 1.6ms preprocess, 64.1ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 cell phone, 63.7ms
# Speed: 1.8ms preprocess, 63.7ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 cell phone, 64.1ms
# Speed: 1.7ms preprocess, 64.1ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 cell phone, 63.5ms
# Speed: 1.6ms preprocess, 63.5ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 cell phone, 62.7ms
# Speed: 1.7ms preprocess, 62.7ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 cell phone, 64.5ms
# Speed: 1.3ms preprocess, 64.5ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 cell phone, 64.4ms
# Speed: 1.4ms preprocess, 64.4ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 cell phone, 63.8ms
# Speed: 1.5ms preprocess, 63.8ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 cell phone, 63.8ms
# Speed: 1.2ms preprocess, 63.8ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 cell phone, 61.9ms
# Speed: 1.3ms preprocess, 61.9ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 cell phone, 62.1ms
# Speed: 1.5ms preprocess, 62.1ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 cell phone, 63.7ms
# Speed: 1.2ms preprocess, 63.7ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 cell phone, 64.9ms
# Speed: 1.4ms preprocess, 64.9ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 remote, 63.9ms
# Speed: 1.3ms preprocess, 63.9ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 remote, 64.1ms
# Speed: 1.3ms preprocess, 64.1ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 cell phone, 64.7ms
# Speed: 1.4ms preprocess, 64.7ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 cell phone, 64.7ms
# Speed: 1.2ms preprocess, 64.7ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 cell phone, 64.4ms
# Speed: 1.3ms preprocess, 64.4ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 remote, 63.3ms
# Speed: 1.4ms preprocess, 63.3ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 cell phone, 63.7ms
# Speed: 1.7ms preprocess, 63.7ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 cell phone, 64.9ms
# Speed: 1.4ms preprocess, 64.9ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 cell phone, 64.0ms
# Speed: 1.3ms preprocess, 64.0ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 cell phone, 64.0ms
# Speed: 1.3ms preprocess, 64.0ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 cell phone, 62.8ms
# Speed: 1.4ms preprocess, 62.8ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 cell phone, 62.8ms
# Speed: 1.6ms preprocess, 62.8ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 cell phone, 62.9ms
# Speed: 1.3ms preprocess, 62.9ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 remote, 63.8ms
# Speed: 1.7ms preprocess, 63.8ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 remote, 63.9ms
# Speed: 1.3ms preprocess, 63.9ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 cell phone, 62.3ms
# Speed: 1.3ms preprocess, 62.3ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 cell phone, 64.7ms
# Speed: 1.3ms preprocess, 64.7ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 cell phone, 63.8ms
# Speed: 1.2ms preprocess, 63.8ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 cell phone, 63.1ms
# Speed: 1.3ms preprocess, 63.1ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 cell phone, 64.4ms
# Speed: 1.3ms preprocess, 64.4ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 cell phone, 64.8ms
# Speed: 1.6ms preprocess, 64.8ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 cell phone, 64.6ms
# Speed: 1.4ms preprocess, 64.6ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 cell phone, 63.7ms
# Speed: 1.5ms preprocess, 63.7ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 cell phone, 63.3ms
# Speed: 1.4ms preprocess, 63.3ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 cell phone, 64.1ms
# Speed: 1.3ms preprocess, 64.1ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 cell phone, 65.1ms
# Speed: 1.3ms preprocess, 65.1ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 cell phone, 63.2ms
# Speed: 1.3ms preprocess, 63.2ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 cell phone, 64.1ms
# Speed: 1.4ms preprocess, 64.1ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 cell phone, 63.6ms
# Speed: 1.4ms preprocess, 63.6ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 cell phone, 64.1ms
# Speed: 1.5ms preprocess, 64.1ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 cell phone, 63.2ms
# Speed: 1.4ms preprocess, 63.2ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 cell phone, 63.6ms
# Speed: 1.6ms preprocess, 63.6ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 cell phone, 64.6ms
# Speed: 1.7ms preprocess, 64.6ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 cell phone, 62.7ms
# Speed: 1.3ms preprocess, 62.7ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 cell phone, 65.2ms
# Speed: 1.2ms preprocess, 65.2ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 cell phone, 63.2ms
# Speed: 1.6ms preprocess, 63.2ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 cell phone, 65.4ms
# Speed: 1.7ms preprocess, 65.4ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 cell phone, 63.5ms
# Speed: 1.6ms preprocess, 63.5ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 cell phone, 64.2ms
# Speed: 1.3ms preprocess, 64.2ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 cell phone, 64.5ms
# Speed: 1.3ms preprocess, 64.5ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 cell phone, 62.9ms
# Speed: 1.4ms preprocess, 62.9ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 cell phone, 65.0ms
# Speed: 1.4ms preprocess, 65.0ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 cell phone, 63.4ms
# Speed: 1.7ms preprocess, 63.4ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 cell phone, 63.6ms
# Speed: 1.7ms preprocess, 63.6ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 cell phone, 63.9ms
# Speed: 1.6ms preprocess, 63.9ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 cell phone, 62.6ms
# Speed: 1.3ms preprocess, 62.6ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 cell phone, 62.9ms
# Speed: 1.7ms preprocess, 62.9ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 cell phone, 62.7ms
# Speed: 1.6ms preprocess, 62.7ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 cell phone, 64.4ms
# Speed: 1.3ms preprocess, 64.4ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 cell phone, 63.4ms
# Speed: 1.7ms preprocess, 63.4ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 cell phone, 66.6ms
# Speed: 1.3ms preprocess, 66.6ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 cell phone, 63.8ms
# Speed: 1.2ms preprocess, 63.8ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 cell phone, 64.5ms
# Speed: 1.4ms preprocess, 64.5ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 cell phone, 62.8ms
# Speed: 1.4ms preprocess, 62.8ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 cell phone, 62.7ms
# Speed: 1.6ms preprocess, 62.7ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 cell phone, 62.6ms
# Speed: 1.6ms preprocess, 62.6ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 cell phone, 63.9ms
# Speed: 1.3ms preprocess, 63.9ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 cell phone, 65.0ms
# Speed: 1.6ms preprocess, 65.0ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 cell phone, 63.2ms
# Speed: 1.3ms preprocess, 63.2ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 cell phone, 64.2ms
# Speed: 1.5ms preprocess, 64.2ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 cell phone, 63.4ms
# Speed: 1.3ms preprocess, 63.4ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 cell phone, 62.8ms
# Speed: 1.7ms preprocess, 62.8ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 cell phone, 62.2ms
# Speed: 1.3ms preprocess, 62.2ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 cell phone, 64.6ms
# Speed: 1.6ms preprocess, 64.6ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 cell phone, 63.8ms
# Speed: 1.4ms preprocess, 63.8ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 cell phone, 64.5ms
# Speed: 1.3ms preprocess, 64.5ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 cell phone, 63.3ms
# Speed: 1.4ms preprocess, 63.3ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 cell phone, 64.5ms
# Speed: 1.4ms preprocess, 64.5ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 cell phone, 63.2ms
# Speed: 1.6ms preprocess, 63.2ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 cell phone, 65.0ms
# Speed: 1.4ms preprocess, 65.0ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 cell phone, 64.2ms
# Speed: 1.7ms preprocess, 64.2ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[1], line 33
#      30 while cap.isOpened():
#      31     # Read a frame from the video
#      32     success, frame = cap.read()
# ---> 33     height, width, channels = frame.shape
#      34     a4_width_pixels = width
#      35     a4_height_pixels = height
#
# AttributeError: 'NoneType' object has no attribute 'shape'
